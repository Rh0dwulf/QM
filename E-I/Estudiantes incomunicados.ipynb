# %% [markdown]
# <img src = "LogoUdeA.png">
#
# <h1 align="center"> Simulación: Estudiantes incomunicados (Local choice) </h1>
#
# <h2 align="center"> Rodolfo Restrepo Villegas </h2>
#
# <h3 align="center"> Instituto de Física - Universidad de Antioquia </h3>

# %% [markdown]
# --- ---

# %% [markdown]
# <h3> Resumen, introducción y demás chorradas... </h3>

# %%
#%%%%%%%%%%%%%%%%%%%%%% Preambulo %%%%%%%%%%%%%%%%%%%%%%%%%

# %pylab inline
import numpy as np
import matplotlib.pylab as plt
from mpl_toolkits.mplot3d import Axes3D
import os
#from time import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#%%%%%%%%%%%%%%%%%%%%%% Definiciones %%%%%%%%%%%%%%%%%%%%%%

n =  10000           # Número de repeticiones

L = 0.50             # Probabilidad de la sub-estrategía izquierda  
R = 1 - L            # Probabilidad de la sub-estrategía derecha

Z = 1.0/3.0          # Probabilidad de que mida en 0°
T = 1.0/3.0          # Probabilidad de que mida en 30°
S = 1.0/3.0          # Probabilidad de que mida en 60°


# Número tetráedrico, o número piramidal triangular 
def T_n(n):
    return (n+1)*(n+2)*(n+3)/6
# Este número encuentra el tamaño del arreglo de probabilidades.

#%%%%%%%%%%%%%%%%%%%%%% Algoritmo %%%%%%%%%%%%%%%%%%%%%%%%%

#Se generan diferentes combinaciones de estrategias
def Probabilities(P):
    List = []
    #
    Alpha =  0.0       # Probabilidad de elegir estrategia A
    Beta  =  0.0       # Probabilidad de elegir estrategia B
    Gamma =  0.0       # Probabilidad de elegir estrategia C
    Delta =  0.0       # Probabilidad de elegir estrategia D
    
    delta_p = 1.0/P    # Se define el paso.
    
    # Primer ciclo for: i entre [0,P]. 
    for i in xrange(0, P + 1):
        # Segundo ciclo for: j entre [0,i].
        for j in xrange(0, i + 1):
            # Tercer ciclo for: k entre [0,j].
            for k in xrange(0, j + 1):
                Alpha = 1.0 - i*delta_p
                Beta = delta_p*(i - j)
                Gamma = delta_p*(j - k)
                Delta = 1 - Alpha - Beta - Gamma
                List.append([Alpha, Beta, Gamma, Delta])
                
    return List

def Estrategia(Alpha, Beta, Gamma, Delta, M):
    for i in xrange(n):
        r = np.random.uniform()
        p = np.random.uniform()
        if r <= Alpha:
            if p <= L:
                M.append(['A','A','A'])
            elif L < p <= R + L:
                M.append(['P','P','P'])
        elif Alpha <= r < Alpha + Beta:
            if p <= L:
                M.append(['A','P','P'])
            elif L < p <= R + L:
                M.append(['P','A','A'])
        elif Alpha + Beta <= r < Alpha + Beta + Gamma:
            if p <= L:
                M.append(['P','A','P'])
            elif L < p <= R + L:
                M.append(['A','P','A'])
        elif Alpha + Beta + Gamma <= r <= 1:
            if p <= L:
                M.append(['P','P','A'])
            elif L < p <= R + L:
                M.append(['A','A','P'])
    return M
    
def Alice(M, P, Arreglo):
    #T2_i = time()
    
    # Se inicia el arreglo vacío.
    Arreglo = []
    
    """
    # Se crea la ruta para guardar los datos
    dir_path = os.path.join('Datos', 'Datos_P=' + str(P))
    try:
        # Se crea el directorio
        os.makedirs(dir_path)
    # Si ya existe simplemente lo omite
    except OSError:
        print 'El directorio ya existe y no fue creado'
        pass
    """
    
    # Se crean los .txt
    #archivo = open(os.path.join(dir_path, txtnameA), 'wb')
    
    # Se abre el archivo para guardar los datos
    #archivo = open(os.path.join(dir_path, txtnameA), 'a')
    
    # Para barrer M
    for j in xrange(0,len(M)):
        
        # Se genera la pregunta para alice (0-30-60)
        alice = np.random.randint(0,3) 
        
        # Si alice == 0 => 0 grados
        if alice == 0:
            if M[j][0] == 'A':
                Arreglo.append(['0' '  ' 'A'])
                #archivo.write('0' '  ' 'A' '\n')
            elif M[j][0] == 'P':
                Arreglo.append(['0' '  ' 'P'])
                #archivo.write('0' '  ' 'P' '\n')
                
        # Si alice == 1 => 30 grados
        elif alice == 1:
            if M[j][1] == 'A':
                Arreglo.append(['30' ' ' 'A'])
                #archivo.write('30' ' ' 'A' '\n')
            elif M[j][1] == 'P':
                Arreglo.append(['30' ' ' 'P'])
                #archivo.write('30' ' ' 'P' '\n')
        
        # Si alice == 2 => 60 grados
        elif alice == 2:
            if M[j][2] == 'A':
                Arreglo.append(['60' ' ' 'A'])
                #archivo.write('60' ' ' 'A' '\n')
            elif M[j][2] == 'P':
                Arreglo.append(['60' ' ' 'P'])
                #archivo.write('60' ' ' 'P' '\n')
                
    #archivo.close()
    #T2_f = time()
    #T2_e = T2_f - T2_i
    #print 'Archivo ' + txtnameA +  ' guardado con éxito', 'Tiempor de ejecución:', T2_e
    return Arreglo

def Bob(M, P, Arreglo):
    # Se inicia el arreglo vacío.
    Arreglo = []
    
    """ 
    # Se crea la ruta para guardar los datos
    dir_path = os.path.join('Datos', 'Datos_P=' + str(P))
    try:
        # Se crea el directorio
        os.makedirs(dir_path)
    # Si ya existe simplemente lo omite
    except OSError:
        print 'El directorio ya existe y no fue creado'
        pass
    """
    
    # Se crean los .txt
    #archivo = open(os.path.join(dir_path, txtnameB), 'wb')
    
    # Se abre el archivo para guardar los datos
    #archivo = open(os.path.join(dir_path, txtnameB), 'a')
    
    # Para barrer M
    for j in xrange(0,len(M)):
        
        # Se genera la pregunta para bob (0-30-60)
        bob = np.random.randint(0,3) 
        
        # Si bob == 0 => 0 grados
        if bob == 0:
            if M[j][0] == 'A':
                Arreglo.append(['0' '  ' 'A'])
                #archivo.write('0' '  ' 'A' '\n')
            elif M[j][0] == 'P':
                Arreglo.append(['0' '  ' 'P'])
                #archivo.write('0' '  ' 'P' '\n')
                
        # Si bob == 1 => 30 grados
        elif bob == 1:
            if M[j][1] == 'A':
                Arreglo.append(['30' ' ' 'A'])
                #archivo.write('30' ' ' 'A' '\n')
            elif M[j][1] == 'P':
                Arreglo.append(['30' ' ' 'P'])
                #archivo.write('30' ' ' 'P' '\n')
        
        # Si bob == 2 => 60 grados
        elif bob == 2:
            if M[j][2] == 'A':
                Arreglo.append(['60' ' ' 'A'])
                #archivo.write('60' ' ' 'A' '\n')
            elif M[j][2] == 'P':
                Arreglo.append(['60' ' ' 'P'])
                #archivo.write('60' ' ' 'P' '\n')
                
    #archivo.close()
    #print 'Archivo ' + txtnameB + ' guardado con éxito'
    return Arreglo
    

#%%%%%%%%%%%%%%%%%%%%%% Run it! %%%%%%%%%%%%%%%%%%%%%%%%%
    
def Run(P, funtion, name):
    Prob = funtion(P)
    Matriz_A = []
    Matriz_B = []
    Arreglo_A = []
    Arreglo_B = []
    # Corre sobre los conjuntos de estrategias alpha, beta, gamma, y delta.
    for l in xrange(0, len(Prob)):
        Alpha, Beta, Gamma, Delta = Prob[l]
        # Se devuelve a cero la Lista para el proximo conjunto de probabilidades
        M = []
        # Se invoca la estrategia (arreglo completo de todas las estrategias que se van a jugar) 
        # común a ambos
        Matriz = Estrategia(Alpha, Beta, Gamma, Delta, M)
        # Se invoca a las funcionde de Alice y Bob con sus respectivos .txt
        Alice_A = Alice(Matriz, P, Arreglo_A)
        Bob_B = Bob(Matriz, P, Arreglo_B)
        Matriz_A.append(Alice_A)
        Matriz_B.append(Bob_B)
    
    np.savetxt('../../Datos/Datos_A_' + str(name) + str(P) + '.txt', np.column_stack((Matriz_A)), 
               delimiter='\t', fmt='%s', comments='#', 
               header='Todos los datos de Alice \n Número total de columnas:' + str(len(Prob)))
    np.savetxt('../../Datos/Datos_B_' + str(name) + str(P) + '.txt', np.column_stack((Matriz_B)), 
               delimiter='\t', fmt='%s', comments='#', 
               header='Todos los datos de Bob. \n Número total de columnas:' + str(len(Prob)))
    print 'Done!'
    
        
# Run Forest, Run!
#Run(25, Probabilities, '')

# %%
# %%%%%%%%%%%%%%%%%%%%%% Cargar datos %%%%%%%%%%%%%%%%%%%%%%%%%

def cargar_Alice(txtnameA, P):
    # Se lee la ruta donde están los datos
    dir_path = os.path.join('../../', 'Datos')
    ''' load the file using std open'''
    f = np.loadtxt(os.path.join(dir_path,txtnameA + str(P) + '.txt'), dtype = str)
    return f

def cargar_Bob(txtnameB, P):
    # Se lee la ruta donde están los datos
    dir_path = os.path.join('../../', 'Datos')
    ''' load the file using std open'''
    f = np.loadtxt(os.path.join(dir_path,txtnameB + str(P) + '.txt'), dtype = str)
    return f


P = 20
M_A = cargar_Alice('Datos_A_', P)
M_B = cargar_Bob('Datos_B_', P)

# %%%%%%%%%%%%%%%%%%%%%% Leer datos %%%%%%%%%%%%%%%%%%%%%%%%%

def leer_Alice(Alice, M_A, j, txtnameA, P):
    s = [M_A[:,j],M_A[:,j+1]]
    for i in range(0, len(s[0])):
        l = [s[0][i], s[1][i]]
        Alice.append(l)
    
    #print 'Longitud de Alice: ', len(Alice)
    return Alice

def leer_Bob(Bob, M_B, j, txtnameB, P):
    s = [M_B[:,j],M_B[:,j+1]]
    for i in range(0, len(s[0])):
        l = [s[0][i], s[1][i]]
        Bob.append(l)
    
    #print 'Longitud de Bob: ', len(Bob)
    return Bob

# %%
#%%%%%%%%%%%%%%%%%%%%%% Comparación %%%%%%%%%%%%%%%%%%%%%%%%

#%%%%%%%%%%%%%%%%%%%%%% Fact #1 %%%%%%%%%%%%%%%%%%%%%%%%%%%%

def fact1(A,B):
    C = []
    D = []
    a1 = ['0', 'A']
    b1 = ['30','A']
    c1 = ['60','A']
    a2 = ['0', 'P']
    b2 = ['30','P']
    c2 = ['60','P']
    
    # Posibles Facto #1 = DeltaTheta = 0°:
    for i in xrange(0, len(A)):
        # 0-0, A-A ó 0-0, A-P
        if (A[i] == a1 and B[i] == a1) or (A[i] == a1 and B[i] == a2):
            C.append([A[i],B[i]])
        # 0-0, P-A ó 0-0, P-P
        elif (A[i] == a2 and B[i] == a1) or (A[i] == a2 and B[i] == a2):
            C.append([A[i],B[i]])
        # 30-30, A-A ó 30-30, A-P
        elif (A[i] == b1 and B[i] == b1) or (A[i] == b1 and B[i] == b2):
            C.append([A[i],B[i]])
        # 30-30, P-A ó 30-30, P-P
        elif (A[i] == b2 and B[i] == b1) or (A[i] == b2 and B[i] == b2):
            C.append([A[i],B[i]])
        # 60-60, A-A ó 60-60, A-P
        elif (A[i] == c1 and B[i] == c1) or (A[i] == c1 and B[i] == c2):
            C.append([A[i],B[i]])
        # 60-60, P-A ó 60-60, P-P
        elif (A[i] == c2 and B[i] == c1) or (A[i] == c2 and B[i] == c2):
            C.append([A[i],B[i]])
            
    # Se comprueba cuales de las posibles sirven:
    if len(C) != 0:
        for j in xrange(0, len(C)):
            if C[j][0] == C[j][1]:
                D.append([C[j][0],C[j][1]])
       
        # Facto #1: Coincidencias sobre el total
        f1 = len(D)*1.0/len(C)
    return f1 

#%%%%%%%%%%%%%%%%%%%%%% Fact #2 %%%%%%%%%%%%%%%%%%%%%%%%%%%%

def fact2(A,B):
    C = []
    D = []
    a1 = ['0', 'A']
    b1 = ['30','A']
    c1 = ['60','A']
    a2 = ['0', 'P']
    b2 = ['30','P']
    c2 = ['60','P']
    
    # Posibles Facto #2 = DeltaTheta = 30°:
    for j in xrange(0,  len(A)):
        # Para 0-30:
        # 0-30, A-A ó 30-0, A-A
        if (A[j] == a1 and B[j] == b1) or (A[j] == b1 and B[j] == a1):
            C.append([A[j],B[j]])
        # 0-30, A-P ó 30-0, P-A
        elif (A[j] == a1 and B[j] == b2) or (A[j] == b2 and B[j] == a1):
            C.append([A[j],B[j]])
        # 0-30, P-P ó 30-0, P-P 
        elif (A[j] == a2 and B[j] == b2) or (A[j] == b2 and B[j] == a2):
            C.append([A[j],B[j]])
        # 0-30, P-A ó 30-0, A-P
        elif (A[j] == a2 and B[j] == b1) or (A[j] == b1 and B[j] == a2):
            C.append([A[j],B[j]])
            
        # Para 30-60:
        # 
        elif (A[j] == b1 and B[j] == c1) or (A[j] == c1 and B[j] == b1):
            C.append([A[j],B[j]])
        elif (A[j] == b1 and B[j] == c2) or (A[j] == c2 and B[j] == b1):
            C.append([A[j],B[j]])
        elif (A[j] == b2 and B[j] == c2) or (A[j] == c2 and B[j] == b2):
            C.append([A[j],B[j]])
        elif (A[j] == b2 and B[j] == c1) or (A[j] == c1 and B[j] == b2):
            C.append([A[j],B[j]])
            
    # Se comprueba cuales de las posibles sirven:
    if len(C) != 0:
        for i in xrange(0, len(C)):
            if (C[i][0] == a1 and C[i][1] == b1) or (C[i][0] == b1 and C[i][1] == a1):
                D.append([C[i][0],C[i][1]])
            elif (C[i][0] == b1 and C[i][1] == c1) or (C[i][0] == c1 and C[i][1] == b1):
                D.append([C[i][0],C[i][1]])
            elif (C[i][0] == a2 and C[i][1] == b2) or (C[i][0] == b2 and C[i][1] == a2):
                D.append([C[i][0],C[i][1]])
            elif (C[i][0] == b2 and C[i][1] == c2) or (C[i][0] == c2 and C[i][1] == b2):
                D.append([C[i][0],C[i][1]])
                
        # Facto #2: Coincidencias sobre el total.
        f2 = len(D)*1.0/len(C)
    return f2

#%%%%%%%%%%%%%%%%%%%%%% Fact #3 %%%%%%%%%%%%%%%%%%%%%%%%%%%%

def fact3(A,B):
    C = []
    D = []
    a1 = ['0', 'A']
    b1 = ['60','A']
    a2 = ['0', 'P']
    b2 = ['60','P']
    
    
    # Posibles Facto #3 = DeltaTheta = 60°:
    for j in xrange(0,  len(A)):
        if (A[j] == a1 and B[j] == b1) or (A[j] == b1 and B[j] == a1):
            C.append([A[j],B[j]])
        elif (A[j] == a2 and B[j] == b2) or (A[j] == b2 and B[j] == a2):
            C.append([A[j],B[j]])
        elif (A[j] == a1 and B[j] == b2) or (A[j] == b2 and B[j] == a1):
            C.append([A[j],B[j]])
        elif (A[j] == a2 and B[j] == b1) or (A[j] == b1 and B[j] == a2):
            C.append([A[j],B[j]])
            
    # Se comprueba cuales de las posibles sirven:
    if len(C) != 0:
        for k in xrange(0, len(C)):
            if (C[k][0] == a1 and C[k][1] == b1) or (C[k][0] == a2 and C[k][1] == b2):
                D.append([C[k][0],C[k][1]])
            elif (C[k][0] == b1 and C[k][1] == a1) or (C[k][0] == b2 and C[k][1] == a2):
                D.append([C[k][0],C[k][1]])
        # Facto #3: Coincidencias sobre el total.
        f3 = len(D)*1.0/len(C)
    return f3
    
#%%%%%%%%%%%%%%%%%%%%%% Fact #0 %%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Se comprueba el Facto #0
def fact0(A,B):
    D = []
    C = []
    a1 = ['0', 'A']
    b1 = ['30','A']
    c1 = ['60','A']
    
    for k in xrange(0, len(A)):
        if(A[k] == a1 or A[k] == b1 or A[k] == c1):
            C.append(A[k])
    print 'Facto #0 para Alice: ', '% de A = ', len(C)*1.0/len(A), '% de P = ', (len(A)-len(C))*1.0/len(A)
    
    for l in xrange(0, len(B)):
        if (B[l] == a1 or B[l] == b1 or B[l] == c1):
            D.append(B[k])
    print 'Facto #0 para Bob: ', '% de A = ', len(D)*1.0/len(B), '% de P = ', (len(B) - len(D))*1.0/len(B) 
    
    
#F1 = fact1(Alice, Bob)
#F2 = fact2(Alice, Bob)
#F3 = fact3(Alice, Bob)
#F0 = fact0(Alice, Bob)

def Run_Facts(P, funtion, txtnameA, txtnameB):
    Prob = funtion(P)
    Flist_2 = []
    Flist_3 = []
    for m in xrange(0, 2*len(Prob), 2):
        Alice = []
        Bob = []
        A_list = leer_Alice(Alice, M_A, m, txtnameA, P)
        B_list = leer_Bob(Bob,M_B, m, txtnameB, P)
        #F0 = fact0(A_list, B_list)
        #F1 = fact1(A_list, B_list)
        F2 = fact2(A_list, B_list)
        F3 = fact3(A_list, B_list)
        Flist_2.append(F2)
        Flist_3.append(F3)
        
        """
        if ((3.0/4.0)*100 - R <= F2 <= (3.0/4.0)*100 + R) or ((1.0/4.0)*100 - R <= F3 <= (1.0/4.0)*100 + R):
            print F2, F3, Prob[m]
        """
    return Flist_2, Flist_3
        

def Ploting_Facts(P, funtion, txtnameA, txtnameB):
    F_2, F_3 = Run_Facts(P, funtion, txtnameA, txtnameB)
    plt.figure(figsize=(10,7))
    plt.plot(F_3, F_2, 'r.')
    plt.plot(0.25,0.75, 'ko', label=r'$|\phi^+>$ ' r'$F_1 = 1.0$')
    plt.plot(0.25,0.375, 'kd', label=r'$|\phi^->$ ' r'$F_1 = 0.5$')
    plt.plot(0.75,0.625, 'kp', label=r'$|\psi^+>$ ' r'$F_1 = 0.5$')
    plt.plot(0.75,1.0, 'ks', label=r'$|\psi^->$ ' r'$F_1 = 0.0$')
    plt.plot(0.5,0.5, 'kv', label=r'$\hat{\rho}_{Max}$ ' r'$F_1 = 0.5$')
    plt.plot(0.25,0.5625, 'k^', label=r'$\hat{\rho}$ ' r'$F_1 = 0.75$')
    plt.axis([-0.1,1.1,-0.1,1.1])
    plt.xlabel('Fact #3', fontsize = 14)
    plt.ylabel('Fact #2', fontsize = 14)
    plt.title('Classical Behavior of Incomunicated Students vs Quantum Entangled Photons' "\n" 
                 r" $\Delta p = %2.2f$"%(1.0/P), fontsize = 14)
    #plt.legend(bbox_to_anchor=(1.25, 1.015), numpoints = 1)
    plt.legend(loc=2, numpoints=1)
    plt.grid(True)
    plt.savefig('Estudiantes_F3vF2_P=' + str(P) + '.png')
    plt.show()
        
Ploting_Facts(P, Probabilities, 'Datos_A_', 'Datos_B_')

# %%
#%%%%%%%%%%%%%%%%%%%%%% Together %%%%%%%%%%%%%%%%%%%%%%%%%%%

def Ploting_T():
    dir_path = os.path.join('../E-I', 'Datos')
    for file in os.listdir("../E-I/Datos"):
        if file.endswith(".txt"):
            f = open(os.path.join(dir_path, file), 'r')
    return f
            
#Ploting_T()

# %%
""" Empezar a escribir, hacer dos enfoques: uno para la geometría y otro para las tampras."""

# Plottea el espacio de probabilidades completo
def Plotting_Prob(P, funtion, name):
    Prob = funtion(P)
    xs = []
    ys = []
    zs = []
    for j in xrange(0, len(Prob)):
        xs.append(Prob[j][0])
        ys.append(Prob[j][1])
        zs.append(Prob[j][2])
    fig = plt.figure(figsize=(10,7))
    axis = fig.add_subplot(111, projection='3d')
    axis.scatter(xs, ys, zs, c='b', marker='.')
    axis.set_xlabel(r'${\alpha}$', fontsize = 15)
    axis.set_ylabel(r'${\beta}$', fontsize = 15)
    axis.set_zlabel(r'${\gamma}$', fontsize = 15)
    axis.grid(True)
    axis.autoscale_view()
    plt.title(r"Space of Probabilities $\alpha$, $\beta$, $\gamma$ ", fontsize = 15)
    axis.view_init(30.0, 30)
    plt.savefig('Probabilities'+ str(name) + '_P=' + str(P) + '.jpg', dpi=fig.dpi)
    plt.show()

# Plottea el espacio de probabilidades para las tapas ("bordes") de dicho espacio.
def Plotting_Prob_Tapas(P, funtion, name):
    Prob = funtion(P)
    xs = []
    ys = []
    zs = []
    Alpha_0 =[]
    Beta_0 = []
    Gamma_0 = []
    for j in xrange(0, len(Prob)):
        xs.append(Prob[j][0])
        ys.append(Prob[j][1])
        zs.append(Prob[j][2])
        if xs[j] == 0:
            Alpha_0.append([ys[j],zs[j]])
        if ys[j] == 0:
            Beta_0.append([xs[j],zs[j]])
        if zs[j] == 0:
            Gamma_0.append([xs[j],ys[j]])
    fig = plt.figure(figsize=(10,7))
    axis = fig.add_subplot(111, projection='3d')
    #axis.scatter(xs, ys, zs, c='b', marker='.')
    for l in xrange(0, len(Alpha_0)):
        scatter1 = axis.scatter(0, Alpha_0[l][0], Alpha_0[l][1], c='b', marker='D')
        scatter2 = axis.scatter(Beta_0[l][0], 0, Beta_0[l][1], c='r', marker='D')
        scatter3 =axis.scatter(Gamma_0[l][0],Gamma_0[l][1], 0, c='g', marker='D')
    axis.set_xlabel(r'${\alpha}$', fontsize = 15)
    axis.set_ylabel(r'${\beta}$', fontsize = 15)
    axis.set_zlabel(r'${\gamma}$', fontsize = 15)
    axis.legend([scatter1, scatter2,  scatter3], [r'$\alpha = 0$ ', r'$\beta = 0$', r'$\gamma = 0$'], 
                numpoints = 1)
    axis.grid(True)
    axis.autoscale_view()
    plt.title(r"Space of Probabilities $\alpha$, $\beta$, $\gamma$", fontsize = 15)
    axis.view_init(30.0, 30)
    #plt.savefig('Probabilities' + str(name) + '_P=' + str(P) + '.jpg', dpi=fig.dpi)
    plt.show()

def Run_Facts_Caras(P, funtion, txtnameA, txtnameB):
    Prob = funtion(P)
    FlistA_2 = []
    FlistA_3 = []
    FlistB_2 = []
    FlistB_3 = []
    FlistC_2 = []
    FlistC_3 = []
    for m in xrange(0, 2*len(Prob), 2):
        if Prob[m/2][0] == 0:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameB, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistA_2.append(F2)
            FlistA_3.append(F3)
        elif Prob[m/2][1] == 0:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameB, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistB_2.append(F2)
            FlistB_3.append(F3)
        elif Prob[m/2][2] == 0:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameB, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistC_2.append(F2)
            FlistC_3.append(F3)
            
    return FlistA_2, FlistA_3, FlistB_2, FlistB_3, FlistC_2, FlistC_3

def Run_Facts_Planos(P, estrategia, funtion, txtnameA, txtnameB):
    Prob = funtion(P)
    FlistA_2 = []
    FlistA_3 = []
    FlistB_2 = []
    FlistB_3 = []
    FlistC_2 = []
    FlistC_3 = []
    for m in xrange(0, 2*len(Prob), 2):
        if 0 <= Prob[m/2][estrategia] <= 1/P:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameB, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistA_2.append(F2)
            FlistA_3.append(F3)
        elif 0.5 <= Prob[m/2][estrategia] <= 0.5 + 1.0/P:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameA, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistB_2.append(F2)
            FlistB_3.append(F3)
        elif 0.9 <= Prob[m/2][estrategia] <= 0.9 + 1.0/P:
            Alice = []
            Bob = []
            A_list = leer_Alice(Alice, m, txtnameA, P)
            B_list = leer_Bob(Bob, m, txtnameA, P)
            #F0 = fact0(A_list, B_list)
            #F1 = fact1(A_list, B_list)
            F2 = fact2(A_list, B_list)
            F3 = fact3(A_list, B_list)
            FlistC_2.append(F2)
            FlistC_3.append(F3)
            
    return FlistA_2, FlistA_3, FlistB_2, FlistB_3, FlistC_2, FlistC_3
                
def Ploting_Facts_Caras(P, funtion , cara, txtnameA, txtnameB):
    FA_2, FA_3, FB_2, FB_3, FC_2, FC_3 = Run_Facts_Caras(P, funtion, txtnameA, txtnameB)
    plt.figure(figsize=(10,7))
    plt.plot(FA_3, FA_2, 'bD', label=r'$\alpha = 0$')
    plt.plot(FB_3, FB_2, 'r.',label=r'$\beta = 0$')
    plt.plot(FC_3, FC_2, 'g*', label=r'$\gamma = 0$')
    plt.plot(25,75, 'ko', label="Q")
    plt.xlabel('Fact #3')
    plt.ylabel('Fact #2')
    plt.suptitle('Classical Behavior of Incomunicated Students', fontsize = 14)
    plt.legend(loc=2)
    plt.grid(True)
    plt.savefig('EstudiantesCaras_F3vF2_P=' + str(P) + '_Cara=' + str(cara)+ '.png')
    plt.show()
    
def Ploting_Facts_Planos(P, estrategia, funtion , cara, txtnameA, txtnameB):
    FA_2, FA_3, FB_2, FB_3, FC_2, FC_3 = Run_Facts_Planos(P, estrategia, funtion, txtnameA, txtnameB)
    plt.figure(figsize=(10,7))
    plt.plot(FA_3, FA_2, 'bD', label=r'$\alpha = 0$')
    plt.plot(FB_3, FB_2, 'r.',label=r'$\alpha = 0$')
    plt.plot(FC_3, FC_2, 'g*', label=r'$\gamma = 0$')
    plt.plot(25,75, 'ko', label="Q")
    plt.xlabel('Fact #3')
    plt.ylabel('Fact #2')
    plt.suptitle('Classical Behavior of Incomunicated Students', fontsize = 14)
    plt.legend(loc=2)
    plt.grid(True)
    plt.savefig('EstudiantesCaras_F3vF2_P=' + str(P) + '_Plano=' + str(cara)+ '.png')
    plt.show()
    
Plotting_Prob_Tapas(20, Probabilities, 'Caras')
#Ploting_Facts_Caras(10, Probabilities, 'Todas', 'Datos_A_', 'Datos_B_')

# %%
# Una distribución aleatoria de puntos dentro del espacio de parámetros

def Random_Prob(P):
    List = []
    
    while (len(List) < T_n(P)):
        Alpha =  np.random.uniform()       # Probabilidad de elegir estrategia A
        Beta  =  np.random.uniform()       # Probabilidad de elegir estrategia B
        Gamma =  np.random.uniform()       # Probabilidad de elegir estrategia C
        #Delta =  np.random.uniform()       # Probabilidad de elegir estrategia D
        if Alpha + Beta + Gamma <= 1:
            Delta = 1 - (Alpha + Beta + Gamma)
            List.append([Alpha, Beta, Gamma, Delta])

    return List

def Random_Prob_CaraABC(P):
    List = []
    
    while (len(List) < T_n(P)):
        Alpha =  np.random.uniform()       # Probabilidad de elegir estrategia A
        Beta  =  np.random.uniform()       # Probabilidad de elegir estrategia B
        #Gamma =  np.random.uniform()       # Probabilidad de elegir estrategia C
        #Delta =  np.random.uniform()       # Probabilidad de elegir estrategia D
        if Alpha + Beta <= 1:
            Gamma = 1 - (Alpha + Beta)
            Delta = 0
            List.append([Alpha, Beta, Gamma, Delta])

    return List

#Plotting_Prob(25, Random_Prob, 'Random')
#Ploting_Facts_Caras(5, Random_Prob, 'TodasRandom', 'Datos_A_Random', 'Datos_B_Random')
#Run_Facts_Plano(5, Random_Prob_CaraABC,'Datos_A_Random', 'Datos_B_Random')

# %%
T_n(25)
# Out:
# 3276

# %%
2*488.3*T_n(50)/1024
